# %%
import pandas as pd
import seaborn as sns; sns.set();
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %pwd
# Out:
# '/home/localadmin/Documents/DataSci'

# %%
#opening the data set and storing in Pandas dataframe "df"
f = open('/home/localadmin/business.csv','r')
df = pd.read_csv(f);
counties = df.iloc[:,1].astype('category')
uniques = pd.unique(counties)

# %%
#using PCA dimenstionality reduction on Captial investments, new jobs, revenue to generalize "success"
def calculate(s,writer):
    pca = PCA(n_components=1)
    pca.fit(df.iloc[:,6:9])
    tmp = df[df['County']== s]
    impact_pca = pd.DataFrame(pca.transform(tmp.iloc[:,6:9].values))
    codes = pd.DataFrame(tmp.iloc[:,12].values)
    df_new = pd.concat([codes,impact_pca],axis=1)
    df_new.columns = ["NAICS Code","Success"]
    ret = df_new.groupby("NAICS Code")["Success"].mean().reset_index().sort_values("Success",ascending=False)
    ret['County'] = s
    ret.to_excel(writer,sheet_name=s)
    print(np.cumsum(pca.explained_variance_ratio_))
  
    return pd.DataFrame(ret)

# %%
df2 = pd.DataFrame()
with pd.ExcelWriter('output.xlsx') as writer:
    for name in uniques:
        calculate(name,writer)
# Out:
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]
# [0.62702034]

# %%
g = open("/home/localadmin/Documents/DataSci/outputin.csv")
df1 = pd.read_csv(g);

# %%
sns.set(style='ticks')
plot = sns.stripplot(x="NAICS Code", y="Success",data=df1, hue='County', size=5)
figure = plot.get_figure()
figure.set_size_inches(12,18)
